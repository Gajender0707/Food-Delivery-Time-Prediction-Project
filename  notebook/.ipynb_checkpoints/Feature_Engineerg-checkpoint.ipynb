# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pwd
# Out:
# '/Users/sanju/Documents/DS/ML /ML Projects/Food Delivery Time Prediction End to End Project/ notebook'

# %%
train_data=pd.read_csv('/Users/sanju/Documents/DS/ML /ML Projects/Food Delivery Time Prediction End to End Project/data/train.csv')
test_data=pd.read_csv("/Users/sanju/Documents/DS/ML /ML Projects/Food Delivery Time Prediction End to End Project/data/test.csv")

# %%
train_data["label"]="Train"
test_data["label"]="Test"

# %%
train_data.columns
# Out:
# Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Order_Date', 'Time_Orderd',
#        'Time_Order_picked', 'Weatherconditions', 'Road_traffic_density',
#        'Vehicle_condition', 'Type_of_order', 'Type_of_vehicle',
#        'multiple_deliveries', 'Festival', 'City', 'Time_taken(min)', 'label'],
#       dtype='object')

# %%
len(train_data.columns)
# Out:
# 21

# %%
train_data['Time_taken(min)']
# Out:
# 0        (min) 24
# 1        (min) 33
# 2        (min) 26
# 3        (min) 21
# 4        (min) 30
#            ...
# 45588    (min) 32
# 45589    (min) 36
# 45590    (min) 16
# 45591    (min) 26
# 45592    (min) 36
# Name: Time_taken(min), Length: 45593, dtype: object

# %%
test_data.columns
# Out:
# Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Order_Date', 'Time_Orderd',
#        'Time_Order_picked', 'Weatherconditions', 'Road_traffic_density',
#        'Vehicle_condition', 'Type_of_order', 'Type_of_vehicle',
#        'multiple_deliveries', 'Festival', 'City', 'label'],
#       dtype='object')

# %%
len(test_data.columns)
# Out:
# 20

# %%
test_data['Time_taken(min)']=np.NaN

# %%
test_data.head(1)
# Out:
#         ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0  0x2318    COIMBRES13DEL01                 NaN                     NaN
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            11.003669             76.976494                   11.043669
#
#    Delivery_location_longitude  Order_Date Time_Orderd  ... Weatherconditions  \
# 0                    77.016494  30-03-2022        NaN   ...    conditions NaN
#
#   Road_traffic_density Vehicle_condition  Type_of_order    Type_of_vehicle  \
# 0                 NaN                  3        Drinks   electric_scooter
#
#   multiple_deliveries Festival            City label Time_taken(min)
# 0                   1      No   Metropolitian   Test             NaN
#
# [1 rows x 21 columns]

# %%
df=pd.concat([train_data,test_data],axis=0)

# %%
df.head()
# Out:
#         ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0  0x4607     INDORES13DEL02                   37                     4.9
# 1  0xb379     BANGRES18DEL02                   34                     4.5
# 2  0x5d6d     BANGRES19DEL01                   23                     4.4
# 3  0x7a6a    COIMBRES13DEL02                   38                     4.7
# 4  0x70a2     CHENRES12DEL01                   32                     4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# 1            12.913041             77.683237                   13.043041
# 2            12.914264             77.678400                   12.924264
# 3            11.003669             76.976494                   11.053669
# 4            12.972793             80.249982                   13.012793
#
#    Delivery_location_longitude  Order_Date Time_Orderd  ...  \
# ...

# %%
df.rename(columns={"Time_taken(min) ":"Time_taken"},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56992 entries, 0 to 11398
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           56992 non-null  object
#  1   Delivery_person_ID           56992 non-null  object
#  2   Delivery_person_Age          56992 non-null  object
#  3   Delivery_person_Ratings      56992 non-null  object
#  4   Restaurant_latitude          56992 non-null  float64
#  5   Restaurant_longitude         56992 non-null  float64
#  6   Delivery_location_latitude   56992 non-null  float64
#  7   Delivery_location_longitude  56992 non-null  float64
#  8   Order_Date                   56992 non-null  object
#  9   Time_Orderd                  56992 non-null  object
#  10  Time_Order_picked            56992 non-null  object
#  11  Weatherconditions            56992 non-null  object
#  12  Road_traffic_density         56992 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# ID                                 0
# Delivery_person_ID                 0
# Delivery_person_Age                0
# Delivery_person_Ratings            0
# Restaurant_latitude                0
# Restaurant_longitude               0
# Delivery_location_latitude         0
# Delivery_location_longitude        0
# Order_Date                         0
# Time_Orderd                        0
# Time_Order_picked                  0
# Weatherconditions                  0
# Road_traffic_density               0
# Vehicle_condition                  0
# Type_of_order                      0
# Type_of_vehicle                    0
# multiple_deliveries                0
# Festival                           0
# City                               0
# Time_taken(min)                11399
# label                              0
# dtype: int64

# %%
df.describe()
# Out:
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# count         56992.000000          56992.000000                56992.000000
# mean             17.034171             70.264920                   17.486049
# std               8.186784             22.861487                    7.325665
# min             -30.905562            -88.400467                    0.010000
# 25%              12.933284             73.170283                   12.989166
# 50%              18.551440             75.897429                   18.636258
# 75%              22.728163             78.045359                   22.785536
# max              30.914057             88.433452                   31.054057
#
#        Delivery_location_longitude  Vehicle_condition
# count                 56992.000000       56992.000000
# mean                     70.897002           1.024968
# std                      21.034559           0.839171
# min                       0.010000           0.000000
# ...

# %%
df.drop(["ID","Delivery_person_ID"],axis=1,inplace=True)

# %%
df.head(1)
# Out:
#   Delivery_person_Age Delivery_person_Ratings  Restaurant_latitude  \
# 0                  37                     4.9            22.745049
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             75.892471                   22.765049
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# 0                    75.912471  19-03-2022    11:30:00          11:45:00
#
#   Weatherconditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0  conditions Sunny                High                   2        Snack
#
#   Type_of_vehicle multiple_deliveries Festival    City Time_taken(min)  label
# 0     motorcycle                    0      No   Urban         (min) 24  Train

# %%
df.shape
# Out:
# (56992, 19)

# %%
df[df["Delivery_person_Age"]=='NaN ']
# Out:
#       Delivery_person_Age Delivery_person_Ratings  Restaurant_latitude  \
# 42                   NaN                     NaN             19.121999
# 74                   NaN                     NaN             12.935662
# 120                  NaN                     NaN             22.312790
# 140                  NaN                     NaN             18.543626
# 179                  NaN                     NaN             26.913483
# ...                   ...                     ...                  ...
# 11268                NaN                     NaN             21.171060
# 11337                NaN                     NaN            -19.176269
# 11343                NaN                     NaN             22.761226
# 11392                NaN                     NaN             18.514210
# 11396                NaN                     NaN             21.157735
#
#        Restaurant_longitude  Delivery_location_latitude  \
# 42                72.908493                   19.201999
# ...

# %%
df["Delivery_person_Age"].value_counts()
# Out:
# Delivery_person_Age
# 35      2809
# 30      2805
# 36      2781
# 37      2776
# 38      2770
# 24      2754
# 28      2748
# 32      2747
# 33      2743
# 29      2739
# 22      2718
# 34      2713
# 26      2704
# 21      2702
# 27      2693
# 20      2691
# 25      2681
# 39      2680
# 31      2655
# 23      2628
# NaN     2345
# 50        63
# 15        47
# Name: count, dtype: int64

# %%
df["Delivery_person_Age"].replace("NaN ",np.nan,inplace=True)
# Out:
# /var/folders/sn/kf4x3ygj0tg81pp8_fswhmp00000gn/T/ipykernel_45891/3571504458.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Delivery_person_Age"].replace("NaN ",np.nan,inplace=True)

# %%
df["Delivery_person_Age"].isnull().sum()
# Out:
# 2345

# %%
df["Delivery_person_Age"].value_counts()
# Out:
# Delivery_person_Age
# 35    2809
# 30    2805
# 36    2781
# 37    2776
# 38    2770
# 24    2754
# 28    2748
# 32    2747
# 33    2743
# 29    2739
# 22    2718
# 34    2713
# 26    2704
# 21    2702
# 27    2693
# 20    2691
# 25    2681
# 39    2680
# 31    2655
# 23    2628
# 50      63
# 15      47
# Name: count, dtype: int64

# %%
# df["Delivery_person_Ratings"]=df["Delivery_person_Ratings"].astype(float)

# %%
df.head(1)
# Out:
#   Delivery_person_Age Delivery_person_Ratings  Restaurant_latitude  \
# 0                  37                     4.9            22.745049
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             75.892471                   22.765049
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# 0                    75.912471  19-03-2022    11:30:00          11:45:00
#
#   Weatherconditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0  conditions Sunny                High                   2        Snack
#
#   Type_of_vehicle multiple_deliveries Festival    City Time_taken(min)  label
# 0     motorcycle                    0      No   Urban         (min) 24  Train

# %%
df["Delivery_person_Ratings"].value_counts()
# Out:
# Delivery_person_Ratings
# 4.8     8938
# 4.9     8904
# 4.7     8865
# 4.6     8603
# 5       4995
# 4.5     4146
# NaN     2415
# 4.2     1769
# 4.3     1750
# 4.1     1741
# 4.4     1687
# 4       1372
# 3.5      315
# 3.7      284
# 3.8      279
# 3.9      259
# 3.6      258
# 6         63
# 1         47
# 3.4       44
# 3.3       38
# 3.1       37
# 3.2       36
# 2.6       34
# 2.7       29
# 2.5       28
# 2.9       26
# 2.8       22
# 3          8
# Name: count, dtype: int64

# %%
df["Delivery_person_Ratings"].replace("NaN ",np.nan,inplace=True)
# Out:
# /var/folders/sn/kf4x3ygj0tg81pp8_fswhmp00000gn/T/ipykernel_45891/2887588998.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Delivery_person_Ratings"].replace("NaN ",np.nan,inplace=True)

# %%
# df["Delivery_person_Age"]=df["Delivery_person_Age"].astype(int)
# df["Delivery_person_Ratings"]=df["Delivery_person_Ratings"].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56992 entries, 0 to 11398
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Delivery_person_Age          54647 non-null  object
#  1   Delivery_person_Ratings      54577 non-null  object
#  2   Restaurant_latitude          56992 non-null  float64
#  3   Restaurant_longitude         56992 non-null  float64
#  4   Delivery_location_latitude   56992 non-null  float64
#  5   Delivery_location_longitude  56992 non-null  float64
#  6   Order_Date                   56992 non-null  object
#  7   Time_Orderd                  56992 non-null  object
#  8   Time_Order_picked            56992 non-null  object
#  9   Weatherconditions            56992 non-null  object
#  10  Road_traffic_density         56992 non-null  object
#  11  Vehicle_condition            56992 non-null  int64
#  12  Type_of_order                56992 non-null  object
# ...

# %%
df["Order_Date"]=pd.to_datetime(df["Order_Date"])
# Out:
# /var/folders/sn/kf4x3ygj0tg81pp8_fswhmp00000gn/T/ipykernel_45891/544640231.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df["Order_Date"]=pd.to_datetime(df["Order_Date"])

# %%
df[df["Order_Date"]=="NaN "]
# Out:
# Empty DataFrame
# Columns: [Delivery_person_Age, Delivery_person_Ratings, Restaurant_latitude, Restaurant_longitude, Delivery_location_latitude, Delivery_location_longitude, Order_Date, Time_Orderd, Time_Order_picked, Weatherconditions, Road_traffic_density, Vehicle_condition, Type_of_order, Type_of_vehicle, multiple_deliveries, Festival, City, Time_taken(min), label]
# Index: []

# %%
df[df["Time_Orderd"]=="NaN "]
# Out:
#       Delivery_person_Age Delivery_person_Ratings  Restaurant_latitude  \
# 42                    NaN                     NaN            19.121999
# 74                    NaN                     NaN            12.935662
# 120                   NaN                     NaN            22.312790
# 140                   NaN                     NaN            18.543626
# 179                   NaN                     NaN            26.913483
# ...                   ...                     ...                  ...
# 11262                  15                       1           -11.003008
# 11268                 NaN                     NaN            21.171060
# 11337                 NaN                     NaN           -19.176269
# 11343                 NaN                     NaN            22.761226
# 11396                 NaN                     NaN            21.157735
#
#        Restaurant_longitude  Delivery_location_latitude  \
# 42                72.908493                   19.201999
# ...

# %%
df["Time_Orderd"].replace("NaN ",np.nan,inplace=True)
# Out:
# /var/folders/sn/kf4x3ygj0tg81pp8_fswhmp00000gn/T/ipykernel_45891/1311066539.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Time_Orderd"].replace("NaN ",np.nan,inplace=True)

# %%
df["Time_Orderd"]=pd.to_datetime(df["Time_Orderd"])
# Out:
# /var/folders/sn/kf4x3ygj0tg81pp8_fswhmp00000gn/T/ipykernel_45891/4168514986.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Time_Orderd"]=pd.to_datetime(df["Time_Orderd"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56992 entries, 0 to 11398
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Delivery_person_Age          54647 non-null  object
#  1   Delivery_person_Ratings      54577 non-null  object
#  2   Restaurant_latitude          56992 non-null  float64
#  3   Restaurant_longitude         56992 non-null  float64
#  4   Delivery_location_latitude   56992 non-null  float64
#  5   Delivery_location_longitude  56992 non-null  float64
#  6   Order_Date                   56992 non-null  datetime64[ns]
#  7   Time_Orderd                  54817 non-null  datetime64[ns]
#  8   Time_Order_picked            56992 non-null  object
#  9   Weatherconditions            56992 non-null  object
#  10  Road_traffic_density         56992 non-null  object
#  11  Vehicle_condition            56992 non-null  int64
# ...

# %%
df[df["Time_Order_picked"]=="NaN "]
# Out:
# Empty DataFrame
# Columns: [Delivery_person_Age, Delivery_person_Ratings, Restaurant_latitude, Restaurant_longitude, Delivery_location_latitude, Delivery_location_longitude, Order_Date, Time_Orderd, Time_Order_picked, Weatherconditions, Road_traffic_density, Vehicle_condition, Type_of_order, Type_of_vehicle, multiple_deliveries, Festival, City, Time_taken(min), label]
# Index: []

# %%
df["Time_Order_picked"]=pd.to_datetime(df["Time_Order_picked"])
# Out:
# /var/folders/sn/kf4x3ygj0tg81pp8_fswhmp00000gn/T/ipykernel_45891/1484207326.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Time_Order_picked"]=pd.to_datetime(df["Time_Order_picked"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56992 entries, 0 to 11398
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Delivery_person_Age          54647 non-null  object
#  1   Delivery_person_Ratings      54577 non-null  object
#  2   Restaurant_latitude          56992 non-null  float64
#  3   Restaurant_longitude         56992 non-null  float64
#  4   Delivery_location_latitude   56992 non-null  float64
#  5   Delivery_location_longitude  56992 non-null  float64
#  6   Order_Date                   56992 non-null  datetime64[ns]
#  7   Time_Orderd                  54817 non-null  datetime64[ns]
#  8   Time_Order_picked            56992 non-null  datetime64[ns]
#  9   Weatherconditions            56992 non-null  object
#  10  Road_traffic_density         56992 non-null  object
#  11  Vehicle_condition            56992 non-null  int64
# ...

# %%
df.head(1)
# Out:
#   Delivery_person_Age Delivery_person_Ratings  Restaurant_latitude  \
# 0                  37                     4.9            22.745049
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             75.892471                   22.765049
#
#    Delivery_location_longitude Order_Date         Time_Orderd  \
# 0                    75.912471 2022-03-19 2024-09-05 11:30:00
#
#     Time_Order_picked Weatherconditions Road_traffic_density  \
# 0 2024-09-05 11:45:00  conditions Sunny                High
#
#    Vehicle_condition Type_of_order Type_of_vehicle multiple_deliveries  \
# 0                  2        Snack      motorcycle                    0
#
#   Festival    City Time_taken(min)  label
# 0      No   Urban         (min) 24  Train

# %%
df["multiple_deliveries"].value_counts()
# Out:
# multiple_deliveries
# 1       35224
# 0       17586
# 2        2498
# NaN      1231
# 3         453
# Name: count, dtype: int64

# %%
df["multiple_deliveries"].replace("NaN ",np.nan,inplace=True)
# Out:
# /var/folders/sn/kf4x3ygj0tg81pp8_fswhmp00000gn/T/ipykernel_45891/2246140089.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["multiple_deliveries"].replace("NaN ",np.nan,inplace=True)

# %%
df["multiple_deliveries"].value_counts()
# Out:
# multiple_deliveries
# 1    35224
# 0    17586
# 2     2498
# 3      453
# Name: count, dtype: int64

# %%
df["multiple_deliveries"].isnull().sum()
# Out:
# 1231

# %%
df["multiple_deliveries"].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 56992 entries, 0 to 11398
# Series name: multiple_deliveries
# Non-Null Count  Dtype
# --------------  -----
# 55761 non-null  object
# dtypes: object(1)
# memory usage: 890.5+ KB

# %%
df.columns
# Out:
# Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Order_Date', 'Time_Orderd',
#        'Time_Order_picked', 'Weatherconditions', 'Road_traffic_density',
#        'Vehicle_condition', 'Type_of_order', 'Type_of_vehicle',
#        'multiple_deliveries', 'Festival', 'City', 'Time_taken(min)', 'label'],
#       dtype='object')

# %%
df["Time_taken(min)"].value_counts()
# Out:
# Time_taken(min)
# (min) 26    2123
# (min) 25    2050
# (min) 27    1976
# (min) 28    1965
# (min) 29    1956
# (min) 19    1824
# (min) 15    1810
# (min) 18    1765
# (min) 16    1706
# (min) 17    1696
# (min) 24    1680
# (min) 23    1643
# (min) 20    1640
# (min) 22    1626
# (min) 21    1601
# (min) 33    1259
# (min) 30    1218
# (min) 31    1213
# (min) 34    1172
# (min) 32    1124
# (min) 38     887
# (min) 36     852
# (min) 39     847
# (min) 35     832
# (min) 37     828
# (min) 11     757
# (min) 10     750
# (min) 12     746
# (min) 14     739
# (min) 13     716
# (min) 43     567
# (min) 42     561
# (min) 40     555
# (min) 41     553
# (min) 44     553
# (min) 47     295
# (min) 49     280
# (min) 48     277
# (min) 46     274
# (min) 45     241
# (min) 53     100
# (min) 51      94
# (min) 54      91
# (min) 52      79
# (min) 50      72
# Name: count, dtype: int64

# %%
df["Time_taken(min)"]
# Out:
# 0        (min) 24
# 1        (min) 33
# 2        (min) 26
# 3        (min) 21
# 4        (min) 30
#            ...
# 11394         NaN
# 11395         NaN
# 11396         NaN
# 11397         NaN
# 11398         NaN
# Name: Time_taken(min), Length: 56992, dtype: object

# %%
df["Time_taken(min)"]=df["Time_taken(min)"].str.strip("(min)")

# %%
df["Time_taken(min)"].isnull().sum()
# Out:
# 11399

# %%
df["Time_taken(min)"].value_counts()
# Out:
# Time_taken(min)
# 26    2123
# 25    2050
# 27    1976
# 28    1965
# 29    1956
# 19    1824
# 15    1810
# 18    1765
# 16    1706
# 17    1696
# 24    1680
# 23    1643
# 20    1640
# 22    1626
# 21    1601
# 33    1259
# 30    1218
# 31    1213
# 34    1172
# 32    1124
# 38     887
# 36     852
# 39     847
# 35     832
# 37     828
# 11     757
# 10     750
# 12     746
# 14     739
# 13     716
# 43     567
# 42     561
# 40     555
# 41     553
# 44     553
# 47     295
# 49     280
# 48     277
# 46     274
# 45     241
# 53     100
# 51      94
# 54      91
# 52      79
# 50      72
# Name: count, dtype: int64

# %%
df["Time_taken(min)"].replace(np.NaN,16,inplace=True)
# Out:
# /var/folders/sn/kf4x3ygj0tg81pp8_fswhmp00000gn/T/ipykernel_45891/1513357585.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Time_taken(min)"].replace(np.NaN,16,inplace=True)

# %%
df["Time_taken(min)"].isnull().sum()
# Out:
# 0

# %%
df["Time_taken(min)"]=df["Time_taken(min)"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56992 entries, 0 to 11398
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Delivery_person_Age          54647 non-null  object
#  1   Delivery_person_Ratings      54577 non-null  object
#  2   Restaurant_latitude          56992 non-null  float64
#  3   Restaurant_longitude         56992 non-null  float64
#  4   Delivery_location_latitude   56992 non-null  float64
#  5   Delivery_location_longitude  56992 non-null  float64
#  6   Order_Date                   56992 non-null  datetime64[ns]
#  7   Time_Orderd                  54817 non-null  datetime64[ns]
#  8   Time_Order_picked            56992 non-null  datetime64[ns]
#  9   Weatherconditions            56992 non-null  object
#  10  Road_traffic_density         56992 non-null  object
#  11  Vehicle_condition            56992 non-null  int64
# ...

# %%
df.head(1)
# Out:
#   Delivery_person_Age Delivery_person_Ratings  Restaurant_latitude  \
# 0                  37                     4.9            22.745049
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             75.892471                   22.765049
#
#    Delivery_location_longitude Order_Date         Time_Orderd  \
# 0                    75.912471 2022-03-19 2024-09-05 11:30:00
#
#     Time_Order_picked Weatherconditions Road_traffic_density  \
# 0 2024-09-05 11:45:00  conditions Sunny                High
#
#    Vehicle_condition Type_of_order Type_of_vehicle multiple_deliveries  \
# 0                  2        Snack      motorcycle                    0
#
#   Festival    City  Time_taken(min)  label
# 0      No   Urban                24  Train

# %%
df.describe()
# Out:
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# count         56992.000000          56992.000000                56992.000000
# mean             17.034171             70.264920                   17.486049
# min             -30.905562            -88.400467                    0.010000
# 25%              12.933284             73.170283                   12.989166
# 50%              18.551440             75.897429                   18.636258
# 75%              22.728163             78.045359                   22.785536
# max              30.914057             88.433452                   31.054057
# std               8.186784             22.861487                    7.325665
#
#        Delivery_location_longitude                     Order_Date  \
# count                 56992.000000                          56992
# mean                     70.897002  2022-03-13 16:37:43.896687360
# min                       0.010000            2022-02-11 00:00:00
# ...

# %%
categorical_columns = df.select_dtypes(include=['object']).columns

print(categorical_columns)
# Out:
# Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Weatherconditions',
#        'Road_traffic_density', 'Type_of_order', 'Type_of_vehicle',
#        'multiple_deliveries', 'Festival', 'City', 'label'],
#       dtype='object')

# %%
categorical_columns=['Weatherconditions', 'Road_traffic_density', 'Type_of_order',
       'Type_of_vehicle', 'Festival', 'City']

# %%
for i in df.columns:
  if df[i].dtypes=="object":
    print(i)
    print(df[i].value_counts())
    print("<<<>>>>"*10)
    print("<<<>>>>"*10)
# Out:
# Delivery_person_Age
# Delivery_person_Age
# 35    2809
# 30    2805
# 36    2781
# 37    2776
# 38    2770
# 24    2754
# 28    2748
# 32    2747
# 33    2743
# 29    2739
# 22    2718
# 34    2713
# 26    2704
# 21    2702
# 27    2693
# 20    2691
# 25    2681
# 39    2680
# 31    2655
# 23    2628
# 50      63
# 15      47
# Name: count, dtype: int64
# <<<>>>><<<>>>><<<>>>><<<>>>><<<>>>><<<>>>><<<>>>><<<>>>><<<>>>><<<>>>>
# <<<>>>><<<>>>><<<>>>><<<>>>><<<>>>><<<>>>><<<>>>><<<>>>><<<>>>><<<>>>>
# Delivery_person_Ratings
# Delivery_person_Ratings
# 4.8    8938
# 4.9    8904
# 4.7    8865
# 4.6    8603
# 5      4995
# 4.5    4146
# 4.2    1769
# 4.3    1750
# 4.1    1741
# 4.4    1687
# 4      1372
# 3.5     315
# 3.7     284
# 3.8     279
# 3.9     259
# 3.6     258
# 6        63
# 1        47
# 3.4      44
# 3.3      38
# 3.1      37
# 3.2      36
# 2.6      34
# 2.7      29
# 2.5      28
# 2.9      26
# 2.8      22
# 3         8
# Name: count, dtype: int64
# ...

# %%
df.tail()
# Out:
#       Delivery_person_Age Delivery_person_Ratings  Restaurant_latitude  \
# 11394                  35                     4.6            26.905190
# 11395                  33                     4.9            26.902940
# 11396                 NaN                     NaN            21.157735
# 11397                  27                     4.7            22.320000
# 11398                  39                       5            13.081878
#
#        Restaurant_longitude  Delivery_location_latitude  \
# 11394             75.810753                   27.015190
# 11395             75.793007                   26.912940
# 11396             72.768778                   21.217735
# 11397             73.170000                   22.450000
# 11398             80.248519                   13.131878
#
#        Delivery_location_longitude Order_Date         Time_Orderd  \
# 11394                    75.920753 2022-03-27 2024-09-05 21:35:00
# ...

# %%
df[df["Weatherconditions"]=="conditions NaN"]
# Out:
#       Delivery_person_Age Delivery_person_Ratings  Restaurant_latitude  \
# 74                    NaN                     NaN            12.935662
# 120                   NaN                     NaN            22.312790
# 250                   NaN                     NaN            18.536718
# 348                   NaN                     NaN            12.935662
# 425                   NaN                     NaN           -30.366322
# ...                   ...                     ...                  ...
# 11210                 NaN                     NaN             0.000000
# 11262                  15                       1           -11.003008
# 11268                 NaN                     NaN            21.171060
# 11337                 NaN                     NaN           -19.176269
# 11396                 NaN                     NaN            21.157735
#
#        Restaurant_longitude  Delivery_location_latitude  \
# 74                77.614130                   12.975662
# ...

# %%
df["Weatherconditions"].replace("conditions NaN","conditions Sunny",inplace=True)
# Out:
# /var/folders/sn/kf4x3ygj0tg81pp8_fswhmp00000gn/T/ipykernel_45891/1405540298.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Weatherconditions"].replace("conditions NaN","conditions Sunny",inplace=True)

# %%
df["Weatherconditions"].value_counts()
# Out:
# Weatherconditions
# conditions Sunny         10033
# conditions Fog            9422
# conditions Stormy         9397
# conditions Cloudy         9397
# conditions Sandstorms     9373
# conditions Windy          9370
# Name: count, dtype: int64

# %%
for i in df.columns:
  if df[i].dtypes=="object":
    print(i)
    print(df[i].value_counts())
    print("<<<>>>>"*10)
    print("<<<>>>>"*10)
# Out:
# Delivery_person_Age
# Delivery_person_Age
# 35    2809
# 30    2805
# 36    2781
# 37    2776
# 38    2770
# 24    2754
# 28    2748
# 32    2747
# 33    2743
# 29    2739
# 22    2718
# 34    2713
# 26    2704
# 21    2702
# 27    2693
# 20    2691
# 25    2681
# 39    2680
# 31    2655
# 23    2628
# 50      63
# 15      47
# Name: count, dtype: int64
# <<<>>>><<<>>>><<<>>>><<<>>>><<<>>>><<<>>>><<<>>>><<<>>>><<<>>>><<<>>>>
# <<<>>>><<<>>>><<<>>>><<<>>>><<<>>>><<<>>>><<<>>>><<<>>>><<<>>>><<<>>>>
# Delivery_person_Ratings
# Delivery_person_Ratings
# 4.8    8938
# 4.9    8904
# 4.7    8865
# 4.6    8603
# 5      4995
# 4.5    4146
# 4.2    1769
# 4.3    1750
# 4.1    1741
# 4.4    1687
# 4      1372
# 3.5     315
# 3.7     284
# 3.8     279
# 3.9     259
# 3.6     258
# 6        63
# 1        47
# 3.4      44
# 3.3      38
# 3.1      37
# 3.2      36
# 2.6      34
# 2.7      29
# 2.5      28
# 2.9      26
# 2.8      22
# 3         8
# Name: count, dtype: int64
# ...

# %%
df[df["Road_traffic_density"]=="Low "]
# Out:
#       Delivery_person_Age Delivery_person_Ratings  Restaurant_latitude  \
# 2                      23                     4.4            12.914264
# 12                     34                     4.3            30.899584
# 20                     31                     4.7            23.357804
# 21                     37                       5            11.003669
# 26                     35                     4.3            21.160522
# ...                   ...                     ...                  ...
# 11388                  39                     4.3            21.149669
# 11390                  31                       5            22.728163
# 11391                  26                     4.8             0.000000
# 11393                  31                     4.7             0.000000
# 11398                  39                       5            13.081878
#
#        Restaurant_longitude  Delivery_location_latitude  \
# 2                 77.678400                   12.924264
# ...

# %%
df["Road_traffic_density"]=df["Road_traffic_density"].replace("NaN ","Low ")

# %%
df["Festival"]=df["Festival"].replace("NaN ","No ")

# %%
df["City"]=df["City"].replace("NaN ","Metropolitian ")

# %%
for i in df.columns:
  if df[i].dtypes=="object":
    print(i)
    print(df[i].value_counts())
    print("<<<>>>>"*10)
    print("<<<>>>>"*10)
# Out:
# Delivery_person_Age
# Delivery_person_Age
# 35    2809
# 30    2805
# 36    2781
# 37    2776
# 38    2770
# 24    2754
# 28    2748
# 32    2747
# 33    2743
# 29    2739
# 22    2718
# 34    2713
# 26    2704
# 21    2702
# 27    2693
# 20    2691
# 25    2681
# 39    2680
# 31    2655
# 23    2628
# 50      63
# 15      47
# Name: count, dtype: int64
# <<<>>>><<<>>>><<<>>>><<<>>>><<<>>>><<<>>>><<<>>>><<<>>>><<<>>>><<<>>>>
# <<<>>>><<<>>>><<<>>>><<<>>>><<<>>>><<<>>>><<<>>>><<<>>>><<<>>>><<<>>>>
# Delivery_person_Ratings
# Delivery_person_Ratings
# 4.8    8938
# 4.9    8904
# 4.7    8865
# 4.6    8603
# 5      4995
# 4.5    4146
# 4.2    1769
# 4.3    1750
# 4.1    1741
# 4.4    1687
# 4      1372
# 3.5     315
# 3.7     284
# 3.8     279
# 3.9     259
# 3.6     258
# 6        63
# 1        47
# 3.4      44
# 3.3      38
# 3.1      37
# 3.2      36
# 2.6      34
# 2.7      29
# 2.5      28
# 2.9      26
# 2.8      22
# 3         8
# Name: count, dtype: int64
# ...

# %%
df.head()
# Out:
#   Delivery_person_Age Delivery_person_Ratings  Restaurant_latitude  \
# 0                  37                     4.9            22.745049
# 1                  34                     4.5            12.913041
# 2                  23                     4.4            12.914264
# 3                  38                     4.7            11.003669
# 4                  32                     4.6            12.972793
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             75.892471                   22.765049
# 1             77.683237                   13.043041
# 2             77.678400                   12.924264
# 3             76.976494                   11.053669
# 4             80.249982                   13.012793
#
#    Delivery_location_longitude Order_Date         Time_Orderd  \
# 0                    75.912471 2022-03-19 2024-09-05 11:30:00
# 1                    77.813237 2022-03-25 2024-09-05 19:45:00
# ...

# %%
df.shape
# Out:
# (56992, 19)

# %%
mydf=df.copy()
mydf_train=mydf[mydf["label"]=="Train"]
mydf_test=mydf[mydf["label"]=="Test"]

# %%
df=pd.get_dummies(df,columns=categorical_columns)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56992 entries, 0 to 11398
# Data columns (total 36 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Delivery_person_Age                      54647 non-null  object
#  1   Delivery_person_Ratings                  54577 non-null  object
#  2   Restaurant_latitude                      56992 non-null  float64
#  3   Restaurant_longitude                     56992 non-null  float64
#  4   Delivery_location_latitude               56992 non-null  float64
#  5   Delivery_location_longitude              56992 non-null  float64
#  6   Order_Date                               56992 non-null  datetime64[ns]
#  7   Time_Orderd                              54817 non-null  datetime64[ns]
#  8   Time_Order_picked                        56992 non-null  datetime64[ns]
#  9   Vehicle_condition                        56992 non-null  int64
# ...

# %%
df.shape
# Out:
# (56992, 36)

# %%
df.head()
# Out:
#   Delivery_person_Age Delivery_person_Ratings  Restaurant_latitude  \
# 0                  37                     4.9            22.745049
# 1                  34                     4.5            12.913041
# 2                  23                     4.4            12.914264
# 3                  38                     4.7            11.003669
# 4                  32                     4.6            12.972793
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             75.892471                   22.765049
# 1             77.683237                   13.043041
# 2             77.678400                   12.924264
# 3             76.976494                   11.053669
# 4             80.249982                   13.012793
#
#    Delivery_location_longitude Order_Date         Time_Orderd  \
# 0                    75.912471 2022-03-19 2024-09-05 11:30:00
# 1                    77.813237 2022-03-25 2024-09-05 19:45:00
# ...

# %%
def cov(x):
  if x==True:
    return 1
  else:
    return 0

# %%
cov(False)
# Out:
# 0

# %%
df["Festival_No "].apply(cov)
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 11394    1
# 11395    1
# 11396    1
# 11397    1
# 11398    1
# Name: Festival_No , Length: 56992, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56992 entries, 0 to 11398
# Data columns (total 36 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Delivery_person_Age                      54647 non-null  object
#  1   Delivery_person_Ratings                  54577 non-null  object
#  2   Restaurant_latitude                      56992 non-null  float64
#  3   Restaurant_longitude                     56992 non-null  float64
#  4   Delivery_location_latitude               56992 non-null  float64
#  5   Delivery_location_longitude              56992 non-null  float64
#  6   Order_Date                               56992 non-null  datetime64[ns]
#  7   Time_Orderd                              54817 non-null  datetime64[ns]
#  8   Time_Order_picked                        56992 non-null  datetime64[ns]
#  9   Vehicle_condition                        56992 non-null  int64
# ...

# %%
for i in df.columns:
  if df[i].dtypes=="bool":
    df[i]=df[i].apply(cov)

# %%
df.head()
# Out:
#   Delivery_person_Age Delivery_person_Ratings  Restaurant_latitude  \
# 0                  37                     4.9            22.745049
# 1                  34                     4.5            12.913041
# 2                  23                     4.4            12.914264
# 3                  38                     4.7            11.003669
# 4                  32                     4.6            12.972793
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             75.892471                   22.765049
# 1             77.683237                   13.043041
# 2             77.678400                   12.924264
# 3             76.976494                   11.053669
# 4             80.249982                   13.012793
#
#    Delivery_location_longitude Order_Date         Time_Orderd  \
# 0                    75.912471 2022-03-19 2024-09-05 11:30:00
# 1                    77.813237 2022-03-25 2024-09-05 19:45:00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56992 entries, 0 to 11398
# Data columns (total 36 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Delivery_person_Age                      54647 non-null  object
#  1   Delivery_person_Ratings                  54577 non-null  object
#  2   Restaurant_latitude                      56992 non-null  float64
#  3   Restaurant_longitude                     56992 non-null  float64
#  4   Delivery_location_latitude               56992 non-null  float64
#  5   Delivery_location_longitude              56992 non-null  float64
#  6   Order_Date                               56992 non-null  datetime64[ns]
#  7   Time_Orderd                              54817 non-null  datetime64[ns]
#  8   Time_Order_picked                        56992 non-null  datetime64[ns]
#  9   Vehicle_condition                        56992 non-null  int64
# ...

# %%
df.head(1)
# Out:
#   Delivery_person_Age Delivery_person_Ratings  Restaurant_latitude  \
# 0                  37                     4.9            22.745049
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             75.892471                   22.765049
#
#    Delivery_location_longitude Order_Date         Time_Orderd  \
# 0                    75.912471 2022-03-19 2024-09-05 11:30:00
#
#     Time_Order_picked  Vehicle_condition  ... Type_of_order_Snack   \
# 0 2024-09-05 11:45:00                  2  ...                    1
#
#    Type_of_vehicle_bicycle  Type_of_vehicle_electric_scooter   \
# 0                         0                                 0
#
#    Type_of_vehicle_motorcycle   Type_of_vehicle_scooter   Festival_No   \
# 0                            1                         0             1
#
#    Festival_Yes   City_Metropolitian   City_Semi-Urban   City_Urban
# 0              0                    0                 0            1
#
# [1 rows x 36 columns]

# %%
df["Time_Orderd"].dt.minute
# Out:
# 0        30.0
# 1        45.0
# 2        30.0
# 3         0.0
# 4        30.0
#          ...
# 11394    35.0
# 11395    40.0
# 11396     NaN
# 11397    35.0
# 11398    20.0
# Name: Time_Orderd, Length: 56992, dtype: float64

# %%
df["day"]=df["Order_Date"].dt.day
df["month"]=df["Order_Date"].dt.month
df["year"]=df["Order_Date"].dt.year

# %%
df["Time_Orderd_hour"]=df["Time_Orderd"].dt.hour
df["Time_Orderd_minute"]=df["Time_Orderd"].dt.minute

# %%
df["Time_Order_picked_hour"]=df["Time_Order_picked"].dt.hour
df["Time_Order_picked_minute"]=df["Time_Order_picked"].dt.minute

# %%
df.head(1)
# Out:
#   Delivery_person_Age Delivery_person_Ratings  Restaurant_latitude  \
# 0                  37                     4.9            22.745049
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             75.892471                   22.765049
#
#    Delivery_location_longitude Order_Date         Time_Orderd  \
# 0                    75.912471 2022-03-19 2024-09-05 11:30:00
#
#     Time_Order_picked  Vehicle_condition  ... City_Metropolitian   \
# 0 2024-09-05 11:45:00                  2  ...                   0
#
#    City_Semi-Urban  City_Urban   day  month  year  Time_Orderd_hour  \
# 0                 0           1   19      3  2022              11.0
#
#    Time_Orderd_minute  Time_Order_picked_hour  Time_Order_picked_minute
# 0                30.0                      11                        45
#
# [1 rows x 43 columns]

# %%
df.drop(["Order_Date","Time_Orderd","Time_Order_picked"],axis=1,inplace=True)

# %%
df.shape
# Out:
# (56992, 40)

# %%
df.head(1)
# Out:
#   Delivery_person_Age Delivery_person_Ratings  Restaurant_latitude  \
# 0                  37                     4.9            22.745049
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             75.892471                   22.765049
#
#    Delivery_location_longitude  Vehicle_condition multiple_deliveries  \
# 0                    75.912471                  2                   0
#
#    Time_taken(min)  label  ...  City_Metropolitian   City_Semi-Urban   \
# 0               24  Train  ...                    0                 0
#
#    City_Urban   day  month  year  Time_Orderd_hour  Time_Orderd_minute  \
# 0            1   19      3  2022              11.0                30.0
#
#    Time_Order_picked_hour  Time_Order_picked_minute
# 0                      11                        45
#
# [1 rows x 40 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56992 entries, 0 to 11398
# Data columns (total 40 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Delivery_person_Age                      54647 non-null  object
#  1   Delivery_person_Ratings                  54577 non-null  object
#  2   Restaurant_latitude                      56992 non-null  float64
#  3   Restaurant_longitude                     56992 non-null  float64
#  4   Delivery_location_latitude               56992 non-null  float64
#  5   Delivery_location_longitude              56992 non-null  float64
#  6   Vehicle_condition                        56992 non-null  int64
#  7   multiple_deliveries                      55761 non-null  object
#  8   Time_taken(min)                          56992 non-null  int64
#  9   label                                    56992 non-null  object
# ...

# %% [markdown]
# As Now All the Fields are ready for the model Trainnig now we can train the model

# %%
train_data=df[df["label"]=="Train"]

# %%
train_data.drop("label",axis=1,inplace=True)
# Out:
# /var/folders/sn/kf4x3ygj0tg81pp8_fswhmp00000gn/T/ipykernel_45891/2859048965.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.drop("label",axis=1,inplace=True)

# %%
test_data=df[df["label"]=="Test"]

# %%
test_data.drop("label",axis=1,inplace=True)
# Out:
# /var/folders/sn/kf4x3ygj0tg81pp8_fswhmp00000gn/T/ipykernel_45891/1200657103.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data.drop("label",axis=1,inplace=True)

# %%
train_data.shape
# Out:
# (45593, 39)

# %%
test_data.shape
# Out:
# (11399, 39)

# %%
train_data.head(1)
# Out:
#   Delivery_person_Age Delivery_person_Ratings  Restaurant_latitude  \
# 0                  37                     4.9            22.745049
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             75.892471                   22.765049
#
#    Delivery_location_longitude  Vehicle_condition multiple_deliveries  \
# 0                    75.912471                  2                   0
#
#    Time_taken(min)  Weatherconditions_conditions Cloudy  ...  \
# 0               24                                    0  ...
#
#    City_Metropolitian   City_Semi-Urban   City_Urban   day  month  year  \
# 0                    0                 0            1   19      3  2022
#
#    Time_Orderd_hour  Time_Orderd_minute  Time_Order_picked_hour  \
# 0              11.0                30.0                      11
#
#    Time_Order_picked_minute
# 0                        45
#
# [1 rows x 39 columns]

# %%
### Standard Scalization

# %%
mydf_train
# Out:
#       Delivery_person_Age Delivery_person_Ratings  Restaurant_latitude  \
# 0                      37                     4.9            22.745049
# 1                      34                     4.5            12.913041
# 2                      23                     4.4            12.914264
# 3                      38                     4.7            11.003669
# 4                      32                     4.6            12.972793
# ...                   ...                     ...                  ...
# 45588                  30                     4.8            26.902328
# 45589                  21                     4.6             0.000000
# 45590                  30                     4.9            13.022394
# 45591                  20                     4.7            11.001753
# 45592                  23                     4.9            23.351058
#
#        Restaurant_longitude  Delivery_location_latitude  \
# 0                 75.892471                   22.765049
# ...

# %%
mydf_train.drop("label",axis=1,inplace=True)
# Out:
# /var/folders/sn/kf4x3ygj0tg81pp8_fswhmp00000gn/T/ipykernel_45891/3159398311.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mydf_train.drop("label",axis=1,inplace=True)

# %%
mydf_test['Time_taken(min)'].value_counts()
# Out:
# Time_taken(min)
# 16    11399
# Name: count, dtype: int64

# %%
num_features=mydf_train.select_dtypes([float,int]).columns
cat_features=mydf_train.select_dtypes(object).columns

# %%
num_features
# Out:
# Index(['Restaurant_latitude', 'Restaurant_longitude',
#        'Delivery_location_latitude', 'Delivery_location_longitude',
#        'Vehicle_condition', 'Time_taken(min)'],
#       dtype='object')

# %%
cat_features
# Out:
# Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Weatherconditions',
#        'Road_traffic_density', 'Type_of_order', 'Type_of_vehicle',
#        'multiple_deliveries', 'Festival', 'City'],
#       dtype='object')

# %%
mydf_train.shape
# Out:
# (45593, 18)

# %%
print(len(num_features))
print(len(cat_features))
# Out:
# 6
# 9

# %%
mydf_train["day"]=mydf_train["Order_Date"].dt.day
mydf_train["month"]=mydf_train["Order_Date"].dt.month
mydf_train["year"]=mydf_train["Order_Date"].dt.year
# Out:
# /var/folders/sn/kf4x3ygj0tg81pp8_fswhmp00000gn/T/ipykernel_45891/837205596.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mydf_train["day"]=mydf_train["Order_Date"].dt.day
# /var/folders/sn/kf4x3ygj0tg81pp8_fswhmp00000gn/T/ipykernel_45891/837205596.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mydf_train["month"]=mydf_train["Order_Date"].dt.month
# /var/folders/sn/kf4x3ygj0tg81pp8_fswhmp00000gn/T/ipykernel_45891/837205596.py:3: SettingWithCopyWarning:
# ...

# %%
mydf_train["Time_Orderd_hour"]=mydf_train["Time_Orderd"].dt.hour
mydf_train["Time_Orderd_minute"]=mydf_train["Time_Orderd"].dt.minute
# Out:
# /var/folders/sn/kf4x3ygj0tg81pp8_fswhmp00000gn/T/ipykernel_45891/2357095131.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mydf_train["Time_Orderd_hour"]=mydf_train["Time_Orderd"].dt.hour
# /var/folders/sn/kf4x3ygj0tg81pp8_fswhmp00000gn/T/ipykernel_45891/2357095131.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mydf_train["Time_Orderd_minute"]=mydf_train["Time_Orderd"].dt.minute

# %%
mydf_train["Time_Order_picked_hour"]=mydf_train["Time_Order_picked"].dt.hour
mydf_train["Time_Order_picked_minute"]=mydf_train["Time_Order_picked"].dt.minute
# Out:
# /var/folders/sn/kf4x3ygj0tg81pp8_fswhmp00000gn/T/ipykernel_45891/3323816290.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mydf_train["Time_Order_picked_hour"]=mydf_train["Time_Order_picked"].dt.hour
# /var/folders/sn/kf4x3ygj0tg81pp8_fswhmp00000gn/T/ipykernel_45891/3323816290.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mydf_train["Time_Order_picked_minute"]=mydf_train["Time_Order_picked"].dt.minute

# %%
mydf_train.drop(["Order_Date","Time_Orderd","Time_Order_picked"],axis=1,inplace=True)
# Out:
# /var/folders/sn/kf4x3ygj0tg81pp8_fswhmp00000gn/T/ipykernel_45891/919097466.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mydf_train.drop(["Order_Date","Time_Orderd","Time_Order_picked"],axis=1,inplace=True)

# %%
mydf_train.head(1)
# Out:
#   Delivery_person_Age Delivery_person_Ratings  Restaurant_latitude  \
# 0                  37                     4.9            22.745049
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             75.892471                   22.765049
#
#    Delivery_location_longitude Weatherconditions Road_traffic_density  \
# 0                    75.912471  conditions Sunny                High
#
#    Vehicle_condition Type_of_order  ... Festival    City Time_taken(min) day  \
# 0                  2        Snack   ...      No   Urban               24  19
#
#    month  year  Time_Orderd_hour  Time_Orderd_minute  Time_Order_picked_hour  \
# 0      3  2022              11.0                30.0                      11
#
#    Time_Order_picked_minute
# 0                        45
#
# [1 rows x 22 columns]

# %%
num_features=mydf_train.select_dtypes([float,int]).columns
cat_features=mydf_train.select_dtypes(object).columns

# %%
print(len(num_features))
print(len(cat_features))
# Out:
# 13
# 9

# %%
mydf_test['Order_Date']=pd.to_datetime(mydf_test['Order_Date'])
mydf_test['Time_Orderd']=pd.to_datetime(mydf_test['Time_Orderd'])
mydf_test['Time_Order_picked']=pd.to_datetime(mydf_test['Time_Order_picked'])
# Out:
# /var/folders/sn/kf4x3ygj0tg81pp8_fswhmp00000gn/T/ipykernel_45891/1695708244.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mydf_test['Order_Date']=pd.to_datetime(mydf_test['Order_Date'])
# /var/folders/sn/kf4x3ygj0tg81pp8_fswhmp00000gn/T/ipykernel_45891/1695708244.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mydf_test['Time_Orderd']=pd.to_datetime(mydf_test['Time_Orderd'])
# ...

# %%
mydf_test["day"]=mydf_test["Order_Date"].dt.day
mydf_test["month"]=mydf_test["Order_Date"].dt.month
mydf_test["year"]=mydf_test["Order_Date"].dt.year
# Out:
# /var/folders/sn/kf4x3ygj0tg81pp8_fswhmp00000gn/T/ipykernel_45891/4226157047.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mydf_test["day"]=mydf_test["Order_Date"].dt.day
# /var/folders/sn/kf4x3ygj0tg81pp8_fswhmp00000gn/T/ipykernel_45891/4226157047.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mydf_test["month"]=mydf_test["Order_Date"].dt.month
# /var/folders/sn/kf4x3ygj0tg81pp8_fswhmp00000gn/T/ipykernel_45891/4226157047.py:3: SettingWithCopyWarning:
# ...

# %%
mydf_test["Time_Order_picked_hour"]=mydf_test["Time_Order_picked"].dt.hour
mydf_test["Time_Order_picked_minute"]=mydf_test["Time_Order_picked"].dt.minute
# Out:
# /var/folders/sn/kf4x3ygj0tg81pp8_fswhmp00000gn/T/ipykernel_45891/2048484535.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mydf_test["Time_Order_picked_hour"]=mydf_test["Time_Order_picked"].dt.hour
# /var/folders/sn/kf4x3ygj0tg81pp8_fswhmp00000gn/T/ipykernel_45891/2048484535.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mydf_test["Time_Order_picked_minute"]=mydf_test["Time_Order_picked"].dt.minute

# %%
mydf_test["Time_Orderd_hour"]=mydf_test["Time_Orderd"].dt.hour
mydf_test["Time_Orderd_minute"]=mydf_test["Time_Orderd"].dt.minute
# Out:
# /var/folders/sn/kf4x3ygj0tg81pp8_fswhmp00000gn/T/ipykernel_45891/120097505.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mydf_test["Time_Orderd_hour"]=mydf_test["Time_Orderd"].dt.hour
# /var/folders/sn/kf4x3ygj0tg81pp8_fswhmp00000gn/T/ipykernel_45891/120097505.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mydf_test["Time_Orderd_minute"]=mydf_test["Time_Orderd"].dt.minute

# %%
mydf_test.drop(["Order_Date","Time_Orderd","Time_Order_picked"],axis=1,inplace=True)
# Out:
# /var/folders/sn/kf4x3ygj0tg81pp8_fswhmp00000gn/T/ipykernel_45891/2774957753.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mydf_test.drop(["Order_Date","Time_Orderd","Time_Order_picked"],axis=1,inplace=True)

# %%
mydf_test.head(1)
# Out:
#   Delivery_person_Age Delivery_person_Ratings  Restaurant_latitude  \
# 0                 NaN                     NaN            11.003669
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             76.976494                   11.043669
#
#    Delivery_location_longitude Weatherconditions Road_traffic_density  \
# 0                    77.016494  conditions Sunny                 Low
#
#    Vehicle_condition Type_of_order  ...            City Time_taken(min) label  \
# 0                  3       Drinks   ...  Metropolitian               16  Test
#
#   day  month  year  Time_Order_picked_hour  Time_Order_picked_minute  \
# 0  30      3  2022                      15                         5
#
#    Time_Orderd_hour  Time_Orderd_minute
# 0               NaN                 NaN
#
# [1 rows x 23 columns]

# %%
print(mydf_train.shape)
print(mydf_test.shape)
# Out:
# (45593, 22)
# (11399, 23)

# %%
mydf_test.drop("label",axis=1,inplace=True)
# Out:
# /var/folders/sn/kf4x3ygj0tg81pp8_fswhmp00000gn/T/ipykernel_45891/547505594.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mydf_test.drop("label",axis=1,inplace=True)

# %%
mydf_test.shape
# Out:
# (11399, 22)

# %%
mydf_train.shape
# Out:
# (45593, 22)

# %%
mydf_train.head(1)
# Out:
#   Delivery_person_Age Delivery_person_Ratings  Restaurant_latitude  \
# 0                  37                     4.9            22.745049
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             75.892471                   22.765049
#
#    Delivery_location_longitude Weatherconditions Road_traffic_density  \
# 0                    75.912471  conditions Sunny                High
#
#    Vehicle_condition Type_of_order  ... Festival    City Time_taken(min) day  \
# 0                  2        Snack   ...      No   Urban               24  19
#
#    month  year  Time_Orderd_hour  Time_Orderd_minute  Time_Order_picked_hour  \
# 0      3  2022              11.0                30.0                      11
#
#    Time_Order_picked_minute
# 0                        45
#
# [1 rows x 22 columns]

# %%
mydf_train.columns
# Out:
# Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Weatherconditions',
#        'Road_traffic_density', 'Vehicle_condition', 'Type_of_order',
#        'Type_of_vehicle', 'multiple_deliveries', 'Festival', 'City',
#        'Time_taken(min)', 'day', 'month', 'year', 'Time_Orderd_hour',
#        'Time_Orderd_minute', 'Time_Order_picked_hour',
#        'Time_Order_picked_minute'],
#       dtype='object')

# %%
y=mydf_train['Time_taken(min)']

# %%
y
# Out:
# 0        24
# 1        33
# 2        26
# 3        21
# 4        30
#          ..
# 45588    32
# 45589    36
# 45590    16
# 45591    26
# 45592    36
# Name: Time_taken(min), Length: 45593, dtype: int64

# %%
x=mydf_train.drop("Time_taken(min)",axis=1)

# %%
x
# Out:
#       Delivery_person_Age Delivery_person_Ratings  Restaurant_latitude  \
# 0                      37                     4.9            22.745049
# 1                      34                     4.5            12.913041
# 2                      23                     4.4            12.914264
# 3                      38                     4.7            11.003669
# 4                      32                     4.6            12.972793
# ...                   ...                     ...                  ...
# 45588                  30                     4.8            26.902328
# 45589                  21                     4.6             0.000000
# 45590                  30                     4.9            13.022394
# 45591                  20                     4.7            11.001753
# 45592                  23                     4.9            23.351058
#
#        Restaurant_longitude  Delivery_location_latitude  \
# 0                 75.892471                   22.765049
# ...

# %%
mydf_test.columns
# Out:
# Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Weatherconditions',
#        'Road_traffic_density', 'Vehicle_condition', 'Type_of_order',
#        'Type_of_vehicle', 'multiple_deliveries', 'Festival', 'City',
#        'Time_taken(min)', 'day', 'month', 'year', 'Time_Order_picked_hour',
#        'Time_Order_picked_minute', 'Time_Orderd_hour', 'Time_Orderd_minute'],
#       dtype='object')

# %%
num_features=mydf_train.select_dtypes([float,int]).columns
cat_features=mydf_train.select_dtypes(object).columns

# %%
##Importing the important libraries for the prediction
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
num_pipeline=Pipeline(steps=[(
    "imputer",SimpleImputer(strategy="median")),
    ("sacaler",StandardScaler())
])

# %%
cat_pipeline=Pipeline(steps=[
    ("imputer",SimpleImputer(strategy="most_frequent")),
    ("scaler",OneHotEncoder())
])

# %%
num_pipeline
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                 ('sacaler', StandardScaler())])

# %%
cat_pipeline
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent')),
#                 ('scaler', OneHotEncoder())])

# %%
Preprocessor=ColumnTransformer([
    ("num_pipeline",num_pipeline,num_features),
    ("cat_pipeline",cat_pipeline,cat_features)
])

# %%
Preprocessor
# Out:
# ColumnTransformer(transformers=[('num_pipeline',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('sacaler',
#                                                   StandardScaler())]),
#                                  Index(['Restaurant_latitude', 'Restaurant_longitude',
#        'Delivery_location_latitude', 'Delivery_location_longitude',
#        'Vehicle_condition', 'Time_taken(min)', 'day', 'month', 'year',
#        'Time_Orderd_hour', 'Time_Orderd_minute',...,
#        'Time_Order_picked_minute'],
#       dtype='object')),
#                                 ('cat_pipeline',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('scaler', OneHotEncoder())]),
# ...

# %%
Preprocessor=Preprocessor.fit(mydf_train)

# %%
Preprocessor
# Out:
# ColumnTransformer(transformers=[('num_pipeline',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('sacaler',
#                                                   StandardScaler())]),
#                                  Index(['Restaurant_latitude', 'Restaurant_longitude',
#        'Delivery_location_latitude', 'Delivery_location_longitude',
#        'Vehicle_condition', 'Time_taken(min)', 'day', 'month', 'year',
#        'Time_Orderd_hour', 'Time_Orderd_minute',...,
#        'Time_Order_picked_minute'],
#       dtype='object')),
#                                 ('cat_pipeline',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('scaler', OneHotEncoder())]),
# ...

# %%
import pickle

# %%
with open("Preprocessor.pkl","wb") as f:
  pickle.dump(Preprocessor,f)

# %%
Preprocessor.transform(mydf_train).toarray()
# Out:
# array([[ 0.69973208,  0.24739067,  0.7225403 , ...,  0.        ,
#          0.        ,  1.        ],
#        [-0.50148783,  0.3256468 , -0.60287932, ...,  1.        ,
#          0.        ,  0.        ],
#        [-0.50133841,  0.32543542, -0.61907241, ...,  0.        ,
#          0.        ,  1.        ],
#        ...,
#        [-0.48812769,  0.43748343, -0.60160421, ...,  1.        ,
#          0.        ,  0.        ],
#        [-0.73499834,  0.2951882 , -0.87571867, ...,  1.        ,
#          0.        ,  0.        ],
#        [ 0.77377088,  0.65962231,  0.81333856, ...,  1.        ,
#          0.        ,  0.        ]])
